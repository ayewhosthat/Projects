# %% [markdown]
# ### Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading Data

# %%
file = 'MAL Anime Reviews 85k.csv'
reviews = pd.read_csv(file)
reviews.head()
# Out:
#    Anime Rank                       Anime Title  \
# 0           1  Fullmetal Alchemist: Brotherhood
# 1           1  Fullmetal Alchemist: Brotherhood
# 2           1  Fullmetal Alchemist: Brotherhood
# 3           1  Fullmetal Alchemist: Brotherhood
# 4           1  Fullmetal Alchemist: Brotherhood
#
#                                            Anime URL          Username  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...           tazillo
# 1  https://myanimelist.net/anime/5114/Fullmetal_A...          Archaeon
# 2  https://myanimelist.net/anime/5114/Fullmetal_A...  ChristopherKClaw
# 3  https://myanimelist.net/anime/5114/Fullmetal_A...    literaturenerd
# 4  https://myanimelist.net/anime/5114/Fullmetal_A...     M0nkeyD_Luffy
#
#     Review Date        Episodes Watched  Review Likes  Overall Rating  \
# 0  Jan 25, 2010  64 of 64 episodes seen          3464              10
# 1  Nov 15, 2010  64 of 64 episodes seen          1311               9
# 2   Apr 7, 2015  64 of 64 episodes seen          1113               7
# 3  Apr 25, 2015  64 of 64 episodes seen           704               7
# 4  Jul 29, 2015  64 of 64 episodes seen           446               5
#
#    Story Rating  Animation Rating  Sound Rating  Character Rating  \
# 0            10                 9             9                10
# 1             8                 9             9                 9
# 2             8                 8            10                 6
# 3             8                 8             8                 8
# 4             2                 7             7                 8
#
#    Enjoyment Rating                                             Review
# 0                10  First of all, I have seen the original FMA and...
# 1                 9  Adaptations have long been a thorn in the side...
# 2                 7  Fullmetal Alchemist: Brotherhood gets an immen...
# 3                 8  Overview:\nFMA Brotherhood is an anime that ne...
# 4                 5  Since I couldn't find any legitimate objective...

# %% [markdown]
# ### Let us see what the overall composition of the dataset is in terms of positive/negative reviews:

# %%
score_filter = reviews['Overall Rating'] >= 6
print(len(reviews.loc[score_filter]))
print(len(reviews.loc[~score_filter]))
# Out:
# 70455
# 15498

# %% [markdown]
# For the sake of simplicity, we will classify any review that has an Overall Rating of 6 or more to be Positive, and any review that has an Overall Rating of 5 or less to be Negative.
# If we split this training set based on the number of negative reviews, this gives us around 15500 reviews of each type (Positive/Negative) to train our model with.

# %% [markdown]
# ### Creating a Sentiment column

# %%
reviews['Sentiment'] = reviews['Overall Rating'].apply(lambda rating: 'Positive' if rating >= 6 else 'Negative')
reviews.head()
# Out:
#    Anime Rank                       Anime Title  \
# 0           1  Fullmetal Alchemist: Brotherhood
# 1           1  Fullmetal Alchemist: Brotherhood
# 2           1  Fullmetal Alchemist: Brotherhood
# 3           1  Fullmetal Alchemist: Brotherhood
# 4           1  Fullmetal Alchemist: Brotherhood
#
#                                            Anime URL          Username  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...           tazillo
# 1  https://myanimelist.net/anime/5114/Fullmetal_A...          Archaeon
# 2  https://myanimelist.net/anime/5114/Fullmetal_A...  ChristopherKClaw
# 3  https://myanimelist.net/anime/5114/Fullmetal_A...    literaturenerd
# 4  https://myanimelist.net/anime/5114/Fullmetal_A...     M0nkeyD_Luffy
#
#     Review Date        Episodes Watched  Review Likes  Overall Rating  \
# 0  Jan 25, 2010  64 of 64 episodes seen          3464              10
# 1  Nov 15, 2010  64 of 64 episodes seen          1311               9
# 2   Apr 7, 2015  64 of 64 episodes seen          1113               7
# 3  Apr 25, 2015  64 of 64 episodes seen           704               7
# 4  Jul 29, 2015  64 of 64 episodes seen           446               5
#
#    Story Rating  Animation Rating  Sound Rating  Character Rating  \
# 0            10                 9             9                10
# 1             8                 9             9                 9
# 2             8                 8            10                 6
# 3             8                 8             8                 8
# 4             2                 7             7                 8
#
#    Enjoyment Rating                                             Review  \
# 0                10  First of all, I have seen the original FMA and...
# 1                 9  Adaptations have long been a thorn in the side...
# 2                 7  Fullmetal Alchemist: Brotherhood gets an immen...
# 3                 8  Overview:\nFMA Brotherhood is an anime that ne...
# 4                 5  Since I couldn't find any legitimate objective...
#
#   Sentiment
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Positive
# 4  Negative

# %% [markdown]
# What we have done is assign a sentiment to each review based on the Overall Rating column. This will help us train our model when we split up our data into a test set and a training set.

# %% [markdown]
# ### Creating a training set and test set from our dataframe

# %% [markdown]
# Let's use our score filter from earlier to get the positive and negative reviews and combine them into one, with the positives 'stacked on top' of the negatives.

# %%
positive = reviews.loc[score_filter]
negative = reviews.loc[~score_filter]
positive = positive[:len(negative)]
joined_reviews = pd.concat([positive, negative], axis=0)
joined_reviews
# Out:
#        Anime Rank                       Anime Title  \
# 0               1  Fullmetal Alchemist: Brotherhood
# 1               1  Fullmetal Alchemist: Brotherhood
# 2               1  Fullmetal Alchemist: Brotherhood
# 3               1  Fullmetal Alchemist: Brotherhood
# 5               1  Fullmetal Alchemist: Brotherhood
# ...           ...                               ...
# 85876          99                     Mo Dao Zu Shi
# 85878          99                     Mo Dao Zu Shi
# 85891          99                     Mo Dao Zu Shi
# 85913           9        3-gatsu no Lion 2nd Season
# 85924           9        3-gatsu no Lion 2nd Season
#
#                                                Anime URL          Username  \
# 0      https://myanimelist.net/anime/5114/Fullmetal_A...           tazillo
# 1      https://myanimelist.net/anime/5114/Fullmetal_A...          Archaeon
# 2      https://myanimelist.net/anime/5114/Fullmetal_A...  ChristopherKClaw
# 3      https://myanimelist.net/anime/5114/Fullmetal_A...    literaturenerd
# 5      https://myanimelist.net/anime/5114/Fullmetal_A...         ryuu_zer0
# ...                                                  ...               ...
# 85876  https://myanimelist.net/anime/37208/Mo_Dao_Zu_...          iluvlynx
# 85878  https://myanimelist.net/anime/37208/Mo_Dao_Zu_...      susurro_void
# 85891  https://myanimelist.net/anime/37208/Mo_Dao_Zu_...       BorisThePea
# 85913  https://myanimelist.net/anime/35180/3-gatsu_no...        Obama-Sama
# 85924  https://myanimelist.net/anime/35180/3-gatsu_no...  GregTheBlood1234
#
#         Review Date        Episodes Watched  Review Likes  Overall Rating  \
# 0      Jan 25, 2010  64 of 64 episodes seen          3464              10
# 1      Nov 15, 2010  64 of 64 episodes seen          1311               9
# 2       Apr 7, 2015  64 of 64 episodes seen          1113               7
# 3      Apr 25, 2015  64 of 64 episodes seen           704               7
# 5       Mar 2, 2010  64 of 64 episodes seen           241               9
# ...             ...                     ...           ...             ...
# 85876  Oct 15, 2020  11 of 15 episodes seen             1               4
# 85878  Sep 23, 2020  10 of 15 episodes seen             1               4
# 85891  Jun 28, 2020  15 of 15 episodes seen             0               5
# 85913  Jul 20, 2020  22 of 22 episodes seen             3               5
# 85924  Aug 13, 2020  22 of 22 episodes seen             2               2
#
#        Story Rating  Animation Rating  Sound Rating  Character Rating  \
# 0                10                 9             9                10
# 1                 8                 9             9                 9
# 2                 8                 8            10                 6
# 3                 8                 8             8                 8
# 5                10                 9             8                10
# ...             ...               ...           ...               ...
# 85876             4                 9             0                 5
# 85878             4                 4             6                 4
# 85891             5                10             8                 5
# 85913             3                 8             8                 5
# 85924             1                 3             2                 1
#
#        Enjoyment Rating                                             Review  \
# 0                    10  First of all, I have seen the original FMA and...
# 1                     9  Adaptations have long been a thorn in the side...
# 2                     7  Fullmetal Alchemist: Brotherhood gets an immen...
# 3                     8  Overview:\nFMA Brotherhood is an anime that ne...
# 5                    10  Now, this is a prime example of how to adapt a...
# ...                 ...                                                ...
# 85876                 3  This review is spoiler-free.\nI read the novel...
# 85878                 2  First things first: There are actually 23 epis...
# 85891                 3  [Minimal spoiler review, and relatively short ...
# 85913                 5  In short, I got left Blue balled from this sea...
# 85924                 1  This season had so much potential but failed t...
#
#       Sentiment
# 0      Positive
# 1      Positive
# 2      Positive
# 3      Positive
# 5      Positive
# ...         ...
# 85876  Negative
# 85878  Negative
# 85891  Negative
# 85913  Negative
# 85924  Negative
#
# [30996 rows x 15 columns]

# %% [markdown]
# To summarize the above code cell, we separated the positive and negative reviews into their own respective dataframes. We then took the first 15498 reviews from the positive reviews and joined that subset with the negative reviews to form an evenly distributed new dataframe.

# %%
shuffled_reviews = joined_reviews.reindex(np.random.permutation(joined_reviews.index))
shuffled_reviews
# Out:
#        Anime Rank                            Anime Title  \
# 60793        4167                    Cossette no Shouzou
# 6045          119  Koukaku Kidoutai: Stand Alone Complex
# 8409         1287                                D-Frag!
# 12707        1414                        Itazura na Kiss
# 15388        1518                      Sukitte Ii na yo.
# ...           ...                                    ...
# 12241        1397                             Deca-Dence
# 4092         1120            Toaru Hikuushi e no Tsuioku
# 16875        1579                                    Hal
# 68608          49                       Kimetsu no Yaiba
# 44776        3091                     Sousei no Aquarion
#
#                                                Anime URL     Username  \
# 60793  https://myanimelist.net/anime/514/Cossette_no_...  IceAndCream
# 6045   https://myanimelist.net/anime/467/Koukaku_Kido...     ktulu007
# 8409   https://myanimelist.net/anime/20031/D-Frag/rev...   NullFreaks
# 12707  https://myanimelist.net/anime/3731/Itazura_na_...    Otaku1412
# 15388  https://myanimelist.net/anime/14289/Sukitte_Ii...      jaccart
# ...                                                  ...          ...
# 12241  https://myanimelist.net/anime/40056/Deca-Dence...      Samawon
# 4092   https://myanimelist.net/anime/9000/Toaru_Hikuu...   Piesh00ter
# 16875  https://myanimelist.net/anime/16528/Hal/review...  Oshiroibaba
# 68608  https://myanimelist.net/anime/38000/Kimetsu_no...   HanAsparux
# 44776  https://myanimelist.net/anime/478/Sousei_no_Aq...     ktulu007
#
#         Review Date        Episodes Watched  Review Likes  Overall Rating  \
# 60793   Aug 8, 2010    1 of 3 episodes seen            11               5
# 6045    Dec 3, 2014  26 of 26 episodes seen            29              10
# 8409    May 1, 2018  12 of 12 episodes seen             4              10
# 12707   Oct 1, 2008  25 of 25 episodes seen            17               8
# 15388   Nov 7, 2015  13 of 13 episodes seen             4               6
# ...             ...                     ...           ...             ...
# 12241   Nov 3, 2020  12 of 12 episodes seen             1               8
# 4092   Oct 11, 2020    1 of 1 episodes seen             0               8
# 16875  Apr 16, 2017    1 of 1 episodes seen             1              10
# 68608  Aug 31, 2019  19 of 26 episodes seen           135               3
# 44776  Jul 10, 2012  26 of 26 episodes seen             7               5
#
#        Story Rating  Animation Rating  Sound Rating  Character Rating  \
# 60793             6                10             8                 7
# 6045             10                 9            10                10
# 8409             10                 9             9                10
# 12707             8                 7             7                 8
# 15388             7                 9             9                 6
# ...             ...               ...           ...               ...
# 12241             9                 8             6                 8
# 4092              8                 9             7                10
# 16875            10                 9             9                10
# 68608             7                 9             9                 2
# 44776             4                 5             5                 5
#
#        Enjoyment Rating                                             Review  \
# 60793                 1  This is the. Most. Disturbing. Anime. I. Have....
# 6045                 10  I've talked about Ghost in the Shell before. B...
# 8409                 10  Short and simple: this anime is a MUST.\nTreme...
# 12707                 8  Itazura na Kiss, or &quot;Mischievous Kiss&quo...
# 15388                 5  My main problem with this anime is how damn fr...
# ...                 ...                                                ...
# 12241                 8  Deca-Dence is the underrated gem of its season...
# 4092                  7  It was a great movie with fantastic character ...
# 16875                 9  This is a great filler anime if you want to wa...
# 68608                 4  I don't usually write any reviews for anime, c...
# 44776                 5  Sousei no Aquarion is a mecha anime written by...
#
#       Sentiment
# 60793  Negative
# 6045   Positive
# 8409   Positive
# 12707  Positive
# 15388  Positive
# ...         ...
# 12241  Positive
# 4092   Positive
# 16875  Positive
# 68608  Negative
# 44776  Negative
#
# [30996 rows x 15 columns]

# %% [markdown]
# Now, our review set has been properly shuffled and we are ready to train our model.

# %%
from sklearn.model_selection import train_test_split
# future reference, install scikit-learn with pip but refer to it as sklearn as pip install sklearn is deprecated

# %%
X, y = train_test_split(shuffled_reviews, test_size=0.2, train_size=0.8, random_state=42, shuffle=True)
# X will be our training set and y will be our testing set

# %%
X
# training data
# Out:
#        Anime Rank                                        Anime Title  \
# 4426         1131                                       Gakuen Alice
# 11554        1381                             Tonari no Kaibutsu-kun
# 3500         1101  Dungeon ni Deai wo Motomeru no wa Machigatteir...
# 52164        3548     Isekai Maou to Shoukan Shoujo no Dorei Majutsu
# 41601         287                           Fruits Basket 1st Season
# ...           ...                                                ...
# 24406        1994                                   B: The Beginning
# 1666         1051                                    Mousou Dairinin
# 13776        1456                           Boruto: Naruto the Movie
# 42758         296                              Toki wo Kakeru Shoujo
# 61654        4234                              Chikyuu Shoujo Arjuna
#
#                                                Anime URL        Username  \
# 4426   https://myanimelist.net/anime/74/Gakuen_Alice/...      tsukiichii
# 11554  https://myanimelist.net/anime/14227/Tonari_no_...        xFangero
# 3500   https://myanimelist.net/anime/28121/Dungeon_ni...         Cauthan
# 52164  https://myanimelist.net/anime/37210/Isekai_Mao...       FCalavera
# 41601  https://myanimelist.net/anime/38680/Fruits_Bas...        RTPDJRT1
# ...                                                  ...             ...
# 24406  https://myanimelist.net/anime/32827/B__The_Beg...     Nid_Vicious
# 1666   https://myanimelist.net/anime/323/Mousou_Dairi...          Fallow
# 13776  https://myanimelist.net/anime/28755/Boruto__Na...       Izuka-kun
# 42758  https://myanimelist.net/anime/2236/Toki_wo_Kak...  Swiftshooter13
# 61654  https://myanimelist.net/anime/812/Chikyuu_Shou...     street_carp
#
#         Review Date        Episodes Watched  Review Likes  Overall Rating  \
# 4426    Jun 3, 2012  26 of 26 episodes seen             2               7
# 11554   Aug 3, 2015  10 of 13 episodes seen            11               8
# 3500   Jun 27, 2015  13 of 13 episodes seen            11               6
# 52164  Jul 26, 2018   4 of 12 episodes seen            30               4
# 41601  Aug 12, 2019  18 of 25 episodes seen             6               4
# ...             ...                     ...           ...             ...
# 24406   Oct 3, 2019  12 of 12 episodes seen             1               5
# 1666   Apr 21, 2008  13 of 13 episodes seen           116               9
# 13776   Mar 4, 2017    1 of 1 episodes seen             1               8
# 42758  Oct 24, 2017    1 of 1 episodes seen            12               4
# 61654   Mar 5, 2017  13 of 13 episodes seen             6               1
#
#        Story Rating  Animation Rating  Sound Rating  Character Rating  \
# 4426              7                 6             8                 8
# 11554             9                 9             9                 7
# 3500              6                 7             7                 6
# 52164             3                 5             5                 5
# 41601             4                 9             2                 1
# ...             ...               ...           ...               ...
# 24406             3                 9             3                 4
# 1666              7                 9             7                 9
# 13776             7                 9             9                 7
# 42758             5                 5             3                 3
# 61654             1                 7             9                 1
#
#        Enjoyment Rating                                             Review  \
# 4426                  7  Okay so this is my first anime review so sorry...
# 11554                 1  it was a hella great anime until ((spoiler?)) ...
# 3500                  6  This is a spoiler-free review adapted for this...
# 52164                 6  Well this is trash, I think we can all agree o...
# 41601                 3  Pros:\nBeautiful Art\nCons:\nHorrible soundtra...
# ...                 ...                                                ...
# 24406                 4  Before I start with the actual review, let me ...
# 1666                  8  Paranoia Agent\nNo. episodes - 13\nStory -\nIt...
# 13776                 8  Any fan of the Naruto series would say they ar...
# 42758                 4  Although Einstein’s theory of general relativi...
# 61654                 1  Vacuous at its best, trite for the remainder.\...
#
#       Sentiment
# 4426   Positive
# 11554  Positive
# 3500   Positive
# 52164  Negative
# 41601  Negative
# ...         ...
# 24406  Negative
# 1666   Positive
# 13776  Positive
# 42758  Negative
# 61654  Negative
#
# [24796 rows x 15 columns]

# %%
y
# testing data
# Out:
#        Anime Rank                                        Anime Title  \
# 3705         1106                                   Ichigo Mashimaro
# 13305        1436            Ouritsu Uchuugun: Honneamise no Tsubasa
# 5515         1171                                       Ga-Rei: Zero
# 26291        2076                                    Fate/stay night
# 17020         158                    Cowboy Bebop: Tengoku no Tobira
# ...           ...                                                ...
# 15732        1533                                          Nanbaka 2
# 9676         1328                  Tsurune: Kazemai Koukou Kyuudoubu
# 10989        1363                                 Grisaia no Kajitsu
# 2234         1068                                  Runway de Waratte
# 23005        1930  Maou Gakuin no Futekigousha: Shijou Saikyou no...
#
#                                                Anime URL          Username  \
# 3705   https://myanimelist.net/anime/488/Ichigo_Mashi...        Plucky-San
# 13305  https://myanimelist.net/anime/1034/Ouritsu_Uch...           MrHawky
# 5515   https://myanimelist.net/anime/4725/Ga-Rei__Zer...   instagramposter
# 26291  https://myanimelist.net/anime/356/Fate_stay_ni...  DanteMustDie8907
# 17020  https://myanimelist.net/anime/5/Cowboy_Bebop__...    Lab_Mem_Num001
# ...                                                  ...               ...
# 15732  https://myanimelist.net/anime/34414/Nanbaka_2/...          orkuncan
# 9676   https://myanimelist.net/anime/36653/Tsurune__K...          Foxstens
# 10989  https://myanimelist.net/anime/17729/Grisaia_no...      SensouNoKami
# 2234   https://myanimelist.net/anime/40392/Runway_de_...      sweet_psycho
# 23005  https://myanimelist.net/anime/40496/Maou_Gakui...     anime_as_fuel
#
#         Review Date        Episodes Watched  Review Likes  Overall Rating  \
# 3705    Nov 3, 2016  12 of 12 episodes seen             4               8
# 13305  Jun 21, 2016    1 of 1 episodes seen             6               7
# 5515   Aug 16, 2009  12 of 12 episodes seen             3              10
# 26291  Mar 28, 2015  24 of 24 episodes seen            33               4
# 17020   Apr 7, 2020    1 of 1 episodes seen             1               8
# ...             ...                     ...           ...             ...
# 15732  Mar 22, 2017  12 of 12 episodes seen            23               8
# 9676   Jan 28, 2019  13 of 13 episodes seen             1               8
# 10989   Jun 7, 2015  13 of 13 episodes seen             6               8
# 2234   May 26, 2020  12 of 12 episodes seen             2               8
# 23005  Aug 14, 2020   4 of 13 episodes seen             3               5
#
#        Story Rating  Animation Rating  Sound Rating  Character Rating  \
# 3705              8                 9             7                 7
# 13305             8                 8             4                 7
# 5515             10                10            10                10
# 26291             3                 2             2                 2
# 17020             7                 9            10                 8
# ...             ...               ...           ...               ...
# 15732             7                 7             9                 7
# 9676              8                 8             9                 6
# 10989             8                 9             8                 9
# 2234              8                 9             9                 7
# 23005             1                 5             3                 1
#
#        Enjoyment Rating                                             Review  \
# 3705                  8  Just finished it last night!\nYeah, the overar...
# 13305                 9  Personally, I would like to fly some more into...
# 5515                 10  i personally think this anime has the most pow...
# 26291                 4  Fate/Stay Night - 4/10\nIt looks awfull, art i...
# 17020                 9  Plot: B *Note: it is described as being in bet...
# ...                 ...                                                ...
# 15732                 8  İts literally like 7.5 well i just voted 8 .\n...
# 9676                  7  I didn't plan on writing a review for this but...
# 10989                 8  In writing this review, i have played part of ...
# 2234                  8  Well I gave it a score of: 8\nI really liked a...
# 23005                 4  yes, it's very op protagonist with huge harem....
#
#       Sentiment
# 3705   Positive
# 13305  Positive
# 5515   Positive
# 26291  Negative
# 17020  Positive
# ...         ...
# 15732  Positive
# 9676   Positive
# 10989  Positive
# 2234   Positive
# 23005  Negative
#
# [6200 rows x 15 columns]

# %%
training_sentiments = list(X['Sentiment'])
testing_sentiments = list(y['Sentiment'])

# training_ovr_ratings = list(X['Overall Rating'])
# training_ovr_ratings = list(y['Overall Rating'])

# %%
print(training_sentiments.count('Positive'))
print(training_sentiments.count('Negative'))
# Out:
# 12412
# 12384

# %% [markdown]
# Fairly even split of positives to negatives, let's check the testing set

# %%
print(testing_sentiments.count('Positive'))
print(testing_sentiments.count('Negative'))
# Out:
# 3086
# 3114

# %% [markdown]
# Training set also contains very similar split of positives to negatives

# %% [markdown]
# Now let us collect the actual review text and put them into their respective lists:

# %%
training_reviews = list(X['Review'])
testing_reviews = list(y['Review'])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# tfid gives words that occur very frequently lesser significance (e.g. 'the', 'a', 'and')

# %%
vectorizer = TfidfVectorizer()
training_matrices = vectorizer.fit_transform(training_reviews)
testing_matrices = vectorizer.transform(testing_reviews)
# now that we have created the vector representations, we can train our model by fitting on our data

# %% [markdown]
# ### Which classification model to use?

# %%
from sklearn.metrics import f1_score
# instead of accuracy, which can be misleading due to false positives/false negatives, we use the f1 score as a metric instead

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
nb_model = MultinomialNB()
nb_model.fit(training_matrices, training_sentiments)
f1_score(testing_sentiments, nb_model.predict(testing_matrices), average=None, labels=['Positive', 'Negative'])
# Out:
# array([0.87473391, 0.87843636])

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lreg_model = LogisticRegression()
lreg_model.fit(training_matrices, training_sentiments)
f1_score(testing_sentiments, lreg_model.predict(testing_matrices), average=None, labels=['Positive', 'Negative'])
# Out:
# array([0.88845401, 0.89087428])

# %% [markdown]
# As we can see, our models work pretty well, with around a 87-88% f1 score all around. This is not bad for a basic classifier!
